# %%
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196  Python-3.11.5 torch-2.2.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# Setup complete  (16 CPUs, 15.4 GB RAM, 378.4/952.1 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO


from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/TrafficViolation
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/drive/.shortcut-targets-by-id/1FF1SxssBL4agJWMCeeRuY2DD4IPrvUfq/TrafficViolation
# /content/drive/.shortcut-targets-by-id/1FF1SxssBL4agJWMCeeRuY2DD4IPrvUfq/TrafficViolation

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ue8iA7PaY7r7AN4376VL")
project = rf.workspace("roboflow-universe-projects").project("license-plate-recognition-rxg4e")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# /content/drive/MyDrive/NewOCR/datasets
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 9.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
# ...

# %%
# !ls
# Out:
# roboflow.zip

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ue8iA7PaY7r7AN4376VL")
project = rf.workspace("yololearning-nuega").project("traffic-lights-yulcv")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Traffic-Lights-1 in yolov8:: 100%|██████████| 13760/13760 [01:42<00:00, 133.88it/s]

# %% [markdown]
# Training

# %%
# %cd /content/drive/MyDrive/TrafficViolation/datasets/Traffic-Lights-1/Traffic-Lights-1
# Out:
# /content/drive/.shortcut-targets-by-id/1FF1SxssBL4agJWMCeeRuY2DD4IPrvUfq/TrafficViolation/datasets/Traffic-Lights-1/Traffic-Lights-1

# %% [markdown]
# Training

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/NewOCR/datasets/License-Plate-Recognition-4/data.yaml epochs=50 imgsz=640 plots=True
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 70.1MB/s]
# New https://pypi.org/project/ultralytics/8.1.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=/content/drive/MyDrive/TrafficViolation/datasets/Traffic-Lights-1/Traffic-Lights-1/runs/detect/train4/weights/best.pt data=/content/drive/MyDrive/TrafficViolation/datasets/Traffic-Lights-1/Traffic-Lights-1/data.yaml epochs=10 imgsz=320 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.1.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=/content/drive/MyDrive/TrafficViolation/datasets/Traffic-Lights-1/Traffic-Lights-1/runs/detect/train8/weights/best.pt data=/content/drive/MyDrive/TrafficViolation/datasets/Traffic-Lights-1/Traffic-Lights-1/data.yaml epochs=10 imgsz=320 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.1.45 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Predication for Number Plate

# %%
# !yolo task=detect mode=predict model=license.pt conf=0.1 source=5675618-hd_1920_1080_30fps.mp4 save=True
# Out:
# Ultralytics YOLOv8.0.196  Python-3.11.5 torch-2.2.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/719) c:\Users\Jasmit\Desktop\Weights\5675618-hd_1920_1080_30fps.mp4: 384x640 2 License_Plates, 102.7ms
# video 1/1 (2/719) c:\Users\Jasmit\Desktop\Weights\5675618-hd_1920_1080_30fps.mp4: 384x640 1 License_Plate, 65.1ms
# video 1/1 (3/719) c:\Users\Jasmit\Desktop\Weights\5675618-hd_1920_1080_30fps.mp4: 384x640 1 License_Plate, 64.1ms
# video 1/1 (4/719) c:\Users\Jasmit\Desktop\Weights\5675618-hd_1920_1080_30fps.mp4: 384x640 1 License_Plate, 59.6ms
# video 1/1 (5/719) c:\Users\Jasmit\Desktop\Weights\5675618-hd_1920_1080_30fps.mp4: 384x640 1 License_Plate, 66.4ms
# video 1/1 (6/719) c:\Users\Jasmit\Desktop\Weights\5675618-hd_1920_1080_30fps.mp4: 384x640 1 License_Plate, 57.6ms
# ...

# %%
# !yolo task=detect mode=predict model=license_plate_detector.pt conf=0.45 source=1.jpeg save=True
# Out:
# Ultralytics YOLOv8.0.196  Python-3.11.5 torch-2.2.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# YOLOv8n summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 c:\Users\Jasmit\Desktop\Weights\1.jpeg: 512x640 1 license_plate, 156.3ms
# Speed: 9.5ms preprocess, 156.3ms inference, 7.8ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs\detect\predict7
#  Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# Predication for Traffic

# %%
# !yolo task=detect mode=predict model=traffic.pt conf=0.1 source=5675618-hd_1920_1080_30fps.mp4 save=True
# Out:
# Ultralytics YOLOv8.0.196  Python-3.11.5 torch-2.2.2+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# Model summary (fused): 268 layers, 68126457 parameters, 0 gradients, 257.4 GFLOPs
#
# video 1/1 (1/719) c:\Users\Jasmit\Desktop\Weights\5675618-hd_1920_1080_30fps.mp4: 192x320 2 reds, 284.8ms
# video 1/1 (2/719) c:\Users\Jasmit\Desktop\Weights\5675618-hd_1920_1080_30fps.mp4: 192x320 2 reds, 310.2ms
# video 1/1 (3/719) c:\Users\Jasmit\Desktop\Weights\5675618-hd_1920_1080_30fps.mp4: 192x320 2 reds, 248.3ms
# video 1/1 (4/719) c:\Users\Jasmit\Desktop\Weights\5675618-hd_1920_1080_30fps.mp4: 192x320 2 reds, 251.8ms
# video 1/1 (5/719) c:\Users\Jasmit\Desktop\Weights\5675618-hd_1920_1080_30fps.mp4: 192x320 2 reds, 239.7ms
# video 1/1 (6/719) c:\Users\Jasmit\Desktop\Weights\5675618-hd_1920_1080_30fps.mp4: 192x320 2 reds, 227.2ms
# video 1/1 (7/719) c:\Users\Jasmit\Desktop\Weights\5675618-hd_1920_1080_30fps.mp4: 192x320 2 reds, 224.7ms
# ...
